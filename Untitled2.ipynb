# %%
# !pip3 install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import pandas as pd

df = pd.read_excel('global_co2_concentration.xlsx')
df.head()
# Out:
#         Date  Nb days  Monthly concentration of atmospheric carbon dioxide  \
# 0 1979-01-15       31                                             336.56
# 1 1979-02-15       62                                             337.29
# 2 1979-03-15       90                                             337.88
# 3 1979-04-15      121                                             338.32
# 4 1979-05-15      151                                             338.26
#
#    Rolling yearly average of the concentration of atmospheric carbon dioxide  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    1978-12-15 00:00:00
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
